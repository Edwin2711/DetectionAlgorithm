# %%
# Download TorchVision repo to use some files from
# references/detection
# !pip install pycocotools --quiet
# !git clone https://github.com/pytorch/vision.git
# !git checkout v0.3.0

# !cp vision/references/detection/utils.py ./
# !cp vision/references/detection/transforms.py ./
# !cp vision/references/detection/coco_eval.py ./
# !cp vision/references/detection/engine.py ./
# !cp vision/references/detection/coco_utils.py ./
# Out:
# Cloning into 'vision'...
# remote: Enumerating objects: 321952, done.
# remote: Counting objects: 100% (4974/4974), done.
# remote: Compressing objects: 100% (549/549), done.
# remote: Total 321952 (delta 4572), reused 4787 (delta 4416), pack-reused 316978
# Receiving objects: 100% (321952/321952), 651.65 MiB | 37.11 MiB/s, done.
# Resolving deltas: 100% (295924/295924), done.
# fatal: not a git repository (or any of the parent directories): .git

# %%
# Basic python and ML Libraries
import os
import random
import numpy as np
import pandas as pd
# for ignoring warnings
import warnings
warnings.filterwarnings('ignore')

# We will be reading images using OpenCV
import cv2

# xml library for parsing xml files
from xml.etree import ElementTree as et

# matplotlib for visualization
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# torchvision libraries
import torch
import torchvision
from torchvision import transforms as torchtrans  
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor

# these are the helper libraries imported.
from engine import train_one_epoch, evaluate
import utils
import transforms as T

# for image augmentations
import albumentations as A
from albumentations.pytorch.transforms import ToTensorV2

# %%
# !unzip DataSet3.zip
# Out:
# Archive:  DataSet3.zip
#    creating: DataSet3/train/
#   inflating: DataSet3/train/prueba.jpg
#   inflating: DataSet3/train/prueba.xml
#   inflating: DataSet3/train/prueba10.jpg
#   inflating: DataSet3/train/prueba10.xml
#   inflating: DataSet3/train/prueba11.jpg
#   inflating: DataSet3/train/prueba11.xml
#   inflating: DataSet3/train/prueba12.jpg
#   inflating: DataSet3/train/prueba12.xml
#   inflating: DataSet3/train/prueba13.jpg
#   inflating: DataSet3/train/prueba13.xml
#   inflating: DataSet3/train/prueba14.jpg
#   inflating: DataSet3/train/prueba14.xml
#   inflating: DataSet3/train/prueba15.jpg
#   inflating: DataSet3/train/prueba15.xml
#   inflating: DataSet3/train/prueba16.jpg
#   inflating: DataSet3/train/prueba16.xml
#   inflating: DataSet3/train/prueba17.jpg
#   inflating: DataSet3/train/prueba17.xml
#   inflating: DataSet3/train/prueba18.jpg
#   inflating: DataSet3/train/prueba18.xml
#   inflating: DataSet3/train/prueba19.jpg
#   inflating: DataSet3/train/prueba19.xml
#   inflating: DataSet3/train/Prueba2.jpg
#   inflating: DataSet3/train/Prueba2.xml
#   inflating: DataSet3/train/prueba20.jpg
#   inflating: DataSet3/train/prueba20.xml
#   inflating: DataSet3/train/prueba21.jpg
#   inflating: DataSet3/train/prueba21.xml
#   inflating: DataSet3/train/prueba22.jpg
#   inflating: DataSet3/train/prueba22.xml
#   inflating: DataSet3/train/prueba23.jpg
#   inflating: DataSet3/train/prueba23.xml
#   inflating: DataSet3/train/prueba24.jpg
#   inflating: DataSet3/train/prueba24.xml
#  extracting: DataSet3/train/prueba25.jpg
#   inflating: DataSet3/train/prueba25.xml
#   inflating: DataSet3/train/prueba26.jpg
#   inflating: DataSet3/train/prueba26.xml
#   inflating: DataSet3/train/prueba27.jpg
#   inflating: DataSet3/train/prueba27.xml
#   inflating: DataSet3/train/prueba28.jpg
#   inflating: DataSet3/train/prueba28.xml
#   inflating: DataSet3/train/prueba29.jpg
#   inflating: DataSet3/train/prueba29.xml
#   inflating: DataSet3/train/prueba3.jpg
#   inflating: DataSet3/train/prueba3.xml
#   inflating: DataSet3/train/prueba30.jpg
#   inflating: DataSet3/train/prueba30.xml
#   inflating: DataSet3/train/prueba4.jpg
#   inflating: DataSet3/train/prueba4.xml
#   inflating: DataSet3/train/prueba5.jpg
#   inflating: DataSet3/train/prueba5.xml
#   inflating: DataSet3/train/prueba6.jpg
#   inflating: DataSet3/train/prueba6.xml
#   inflating: DataSet3/train/prueba7.jpg
#   inflating: DataSet3/train/prueba7.xml
#   inflating: DataSet3/train/prueba8.jpg
#   inflating: DataSet3/train/prueba8.xml
#   inflating: DataSet3/train/prueba9.jpg
#   inflating: DataSet3/train/prueba9.xml

# %%
files_dir = 'DataSet3/train/'
test_dir = 'DataSet/validation/'

# %%
class FruitImagesDataset(torch.utils.data.Dataset):

    def __init__(self, files_dir, width, height, transforms=None):
        self.transforms = transforms
        self.files_dir = files_dir
        self.height = height
        self.width = width
        
        # sorting the images for consistency
        # To get images, the extension of the filename is checked to be jpg
        self.imgs = [image for image in sorted(os.listdir(files_dir))
                        if image[-4:]=='.jpg']
        
        
        # classes: 0 index is reserved for background
        self.classes = [_, 'Cylinder']

    def __getitem__(self, idx):

        img_name = self.imgs[idx]
        image_path = os.path.join(self.files_dir, img_name)

        # reading the images and converting them to correct size and color    
        img = cv2.imread(image_path)
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype(np.float32)
        img_res = cv2.resize(img_rgb, (self.width, self.height), cv2.INTER_AREA)
        # diving by 255
        img_res /= 255.0
        
        # annotation file
        annot_filename = img_name[:-4] + '.xml'
        annot_file_path = os.path.join(self.files_dir, annot_filename)
        
        boxes = []
        labels = []
        tree = et.parse(annot_file_path)
        root = tree.getroot()
        
        # cv2 image gives size as height x width
        wt = img.shape[1]
        ht = img.shape[0]
        
        # box coordinates for xml files are extracted and corrected for image size given
        for member in root.findall('object'):
            labels.append(self.classes.index(member.find('name').text))
            
            # bounding box
            xmin = int(member.find('bndbox').find('xmin').text)
            xmax = int(member.find('bndbox').find('xmax').text)
            
            ymin = int(member.find('bndbox').find('ymin').text)
            ymax = int(member.find('bndbox').find('ymax').text)
            
            
            xmin_corr = (xmin/wt)*self.width
            xmax_corr = (xmax/wt)*self.width
            ymin_corr = (ymin/ht)*self.height
            ymax_corr = (ymax/ht)*self.height
            
            boxes.append([xmin_corr, ymin_corr, xmax_corr, ymax_corr])
        
        # convert boxes into a torch.Tensor
        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        
        # getting the areas of the boxes
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])

        # suppose all instances are not crowd
        iscrowd = torch.zeros((boxes.shape[0],), dtype=torch.int64)
        
        labels = torch.as_tensor(labels, dtype=torch.int64)


        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["area"] = area
        target["iscrowd"] = iscrowd
        # image_id
        image_id = torch.tensor([idx])
        target["image_id"] = image_id


        if self.transforms:
            
            sample = self.transforms(image = img_res,
                                     bboxes = target['boxes'],
                                     labels = labels)
            
            img_res = sample['image']
            target['boxes'] = torch.Tensor(sample['bboxes'])
            
            
            
        return img_res, target

    def __len__(self):
        return len(self.imgs)


# check dataset
dataset = FruitImagesDataset(files_dir, 224, 224)
print('length of dataset = ', len(dataset), '\n')

# getting the image and target for a test index.  Feel free to change the index.
img, target = dataset[2]
print(img.shape, '\n',target)
# Out:
# length of dataset =  30
#
# (224, 224, 3)
#  {'boxes': tensor([[ 52.1920,  23.5200, 173.8240, 211.4560]]), 'labels': tensor([1]), 'area': tensor([22859.0312]), 'iscrowd': tensor([0]), 'image_id': tensor([2])}

# %%
# Function to visualize bounding boxes in the image

def plot_img_bbox(img, target):
    # plot the image and bboxes
    # Bounding boxes are defined as follows: x-min y-min width height
    fig, a = plt.subplots(1,1)
    fig.set_size_inches(5,5)
    a.imshow(img)
    for box in (target['boxes']):
        x, y, width, height  = box[0], box[1], box[2]-box[0], box[3]-box[1]
        rect = patches.Rectangle((x, y),
                                 width, height,
                                 linewidth = 2,
                                 edgecolor = 'r',
                                 facecolor = 'none')

        # Draw the bounding box on top of the image
        a.add_patch(rect)
    plt.show()
    
# plotting the image with bboxes. Feel free to change the index
img, target = dataset[9]
plot_img_bbox(img, target)

# %%
def get_object_detection_model(num_classes):

    # load a model pre-trained pre-trained on COCO
    model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)
    
    # get number of input features for the classifier
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    # replace the pre-trained head with a new one
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes) 

    return model

# %%
# Send train=True for training transforms and False for val/test transforms
def get_transform(train):
    
    if train:
        return A.Compose([
                            A.HorizontalFlip(0.5),
                     # ToTensorV2 converts image to pytorch tensor without div by 255
                            ToTensorV2(p=1.0) 
                        ], bbox_params={'format': 'pascal_voc', 'label_fields': ['labels']})
    else:
        return A.Compose([
                            ToTensorV2(p=1.0)
                        ], bbox_params={'format': 'pascal_voc', 'label_fields': ['labels']})

# %%
# use our dataset and defined transformations
dataset = FruitImagesDataset(files_dir, 480, 480, transforms= get_transform(train=True))
dataset_test = FruitImagesDataset(files_dir, 480, 480, transforms= get_transform(train=False))

# %%
# split the dataset in train and test set
torch.manual_seed(1)
indices = torch.randperm(len(dataset)).tolist()

# train test split
test_split = 0.3
tsize = int(len(dataset)*test_split)
dataset = torch.utils.data.Subset(dataset, indices[:-tsize])
dataset_test = torch.utils.data.Subset(dataset_test, indices[-tsize:])

# define training and validation data loaders
data_loader = torch.utils.data.DataLoader(
    dataset, batch_size=10, shuffle=True, num_workers=4,
    collate_fn=utils.collate_fn)

data_loader_test = torch.utils.data.DataLoader(
    dataset_test, batch_size=10, shuffle=False, num_workers=4,
    collate_fn=utils.collate_fn)

# %%
# to train on gpu if selected.
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print(device)

num_classes = 2

# get the model using our helper function
model = get_object_detection_model(num_classes)

# move model to the right device
model.to(device)

# construct an optimizer
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.005,
                            momentum=0.9, weight_decay=0.0005)

# and a learning rate scheduler which decreases the learning rate by
# 10x every 3 epochs
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                               step_size=3,
                                               gamma=0.1)
# Out:
# cuda
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
#   0%|          | 0.00/160M [00:00<?, ?B/s]

# %%
# training for 10 epochs
num_epochs = 15

for epoch in range(num_epochs):
    # training for one epoch
    train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq=10)
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset
    evaluate(model, data_loader_test, device=device)
# Out:
# Epoch: [0]  [0/3]  eta: 0:00:28  lr: 0.002503  loss: 1.0523 (1.0523)  loss_classifier: 0.8936 (0.8936)  loss_box_reg: 0.1393 (0.1393)  loss_objectness: 0.0094 (0.0094)  loss_rpn_box_reg: 0.0100 (0.0100)  time: 9.6070  data: 0.4484  max mem: 8205
# Epoch: [0]  [2/3]  eta: 0:00:03  lr: 0.005000  loss: 1.0269 (0.8156)  loss_classifier: 0.8759 (0.6540)  loss_box_reg: 0.1400 (0.1511)  loss_objectness: 0.0018 (0.0038)  loss_rpn_box_reg: 0.0092 (0.0067)  time: 3.8295  data: 0.1531  max mem: 8473
# Epoch: [0] Total time: 0:00:11 (3.8611 s / it)
# creating index...
# index created!
# Test:  [0/1]  eta: 0:00:01  model_time: 0.6754 (0.6754)  evaluator_time: 0.0037 (0.0037)  time: 1.0179  data: 0.3311  max mem: 8473
# Test: Total time: 0:00:01 (1.1175 s / it)
# Averaged stats: model_time: 0.6754 (0.6754)  evaluator_time: 0.0037 (0.0037)
# Accumulating evaluation results...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Epoch: [1]  [0/3]  eta: 0:00:06  lr: 0.005000  loss: 0.3009 (0.3009)  loss_classifier: 0.1613 (0.1613)  loss_box_reg: 0.1200 (0.1200)  loss_objectness: 0.0112 (0.0112)  loss_rpn_box_reg: 0.0083 (0.0083)  time: 2.0719  data: 0.4085  max mem: 8473
# Epoch: [1]  [2/3]  eta: 0:00:01  lr: 0.005000  loss: 0.3971 (0.3801)  loss_classifier: 0.2524 (0.2354)  loss_box_reg: 0.1200 (0.1240)  loss_objectness: 0.0112 (0.0115)  loss_rpn_box_reg: 0.0083 (0.0092)  time: 1.3191  data: 0.1484  max mem: 8473
# Epoch: [1] Total time: 0:00:04 (1.3497 s / it)
# creating index...
# index created!
# Test:  [0/1]  eta: 0:00:01  model_time: 0.6772 (0.6772)  evaluator_time: 0.0026 (0.0026)  time: 1.2227  data: 0.5352  max mem: 8473
# Test: Total time: 0:00:01 (1.3142 s / it)
# Averaged stats: model_time: 0.6772 (0.6772)  evaluator_time: 0.0026 (0.0026)
# Accumulating evaluation results...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Epoch: [2]  [0/3]  eta: 0:00:06  lr: 0.005000  loss: 0.3677 (0.3677)  loss_classifier: 0.2518 (0.2518)  loss_box_reg: 0.1043 (0.1043)  loss_objectness: 0.0080 (0.0080)  loss_rpn_box_reg: 0.0036 (0.0036)  time: 2.0736  data: 0.3961  max mem: 8473
# Epoch: [2]  [2/3]  eta: 0:00:01  lr: 0.005000  loss: 0.2825 (0.2594)  loss_classifier: 0.1756 (0.1605)  loss_box_reg: 0.0908 (0.0810)  loss_objectness: 0.0080 (0.0063)  loss_rpn_box_reg: 0.0077 (0.0116)  time: 1.3281  data: 0.1455  max mem: 8473
# Epoch: [2] Total time: 0:00:04 (1.3826 s / it)
# creating index...
# index created!
# Test:  [0/1]  eta: 0:00:01  model_time: 0.6922 (0.6922)  evaluator_time: 0.0071 (0.0071)  time: 1.0639  data: 0.3557  max mem: 8473
# Test: Total time: 0:00:01 (1.1946 s / it)
# Averaged stats: model_time: 0.6922 (0.6922)  evaluator_time: 0.0071 (0.0071)
# Accumulating evaluation results...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.128
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.337
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.059
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.128
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.144
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.144
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.144
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.144
# Epoch: [3]  [0/3]  eta: 0:00:06  lr: 0.000500  loss: 0.2031 (0.2031)  loss_classifier: 0.0960 (0.0960)  loss_box_reg: 0.0882 (0.0882)  loss_objectness: 0.0112 (0.0112)  loss_rpn_box_reg: 0.0077 (0.0077)  time: 2.1586  data: 0.4877  max mem: 8473
# Epoch: [3]  [2/3]  eta: 0:00:01  lr: 0.000500  loss: 0.1926 (0.1847)  loss_classifier: 0.0959 (0.0813)  loss_box_reg: 0.0847 (0.0794)  loss_objectness: 0.0112 (0.0106)  loss_rpn_box_reg: 0.0077 (0.0134)  time: 1.3477  data: 0.1656  max mem: 8473
# Epoch: [3] Total time: 0:00:04 (1.3797 s / it)
# creating index...
# index created!
# Test:  [0/1]  eta: 0:00:00  model_time: 0.6860 (0.6860)  evaluator_time: 0.0035 (0.0035)  time: 0.9869  data: 0.2893  max mem: 8473
# Test: Total time: 0:00:01 (1.0796 s / it)
# Averaged stats: model_time: 0.6860 (0.6860)  evaluator_time: 0.0035 (0.0035)
# Accumulating evaluation results...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.182
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.446
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.114
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.182
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.211
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.211
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.211
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.211
# Epoch: [4]  [0/3]  eta: 0:00:06  lr: 0.000500  loss: 0.1872 (0.1872)  loss_classifier: 0.0804 (0.0804)  loss_box_reg: 0.0901 (0.0901)  loss_objectness: 0.0076 (0.0076)  loss_rpn_box_reg: 0.0090 (0.0090)  time: 2.0927  data: 0.3910  max mem: 8473
# Epoch: [4]  [2/3]  eta: 0:00:01  lr: 0.000500  loss: 0.1872 (0.1912)  loss_classifier: 0.0862 (0.0921)  loss_box_reg: 0.0901 (0.0875)  loss_objectness: 0.0048 (0.0048)  loss_rpn_box_reg: 0.0079 (0.0069)  time: 1.3435  data: 0.1424  max mem: 8473
# Epoch: [4] Total time: 0:00:04 (1.3750 s / it)
# creating index...
# index created!
# Test:  [0/1]  eta: 0:00:01  model_time: 0.6999 (0.6999)  evaluator_time: 0.0059 (0.0059)  time: 1.0093  data: 0.2950  max mem: 8473
# Test: Total time: 0:00:01 (1.1805 s / it)
# Averaged stats: model_time: 0.6999 (0.6999)  evaluator_time: 0.0059 (0.0059)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.406
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.859
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.296
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.406
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.467
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.467
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.467
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.467
# Epoch: [5]  [0/3]  eta: 0:00:06  lr: 0.000500  loss: 0.1444 (0.1444)  loss_classifier: 0.0549 (0.0549)  loss_box_reg: 0.0719 (0.0719)  loss_objectness: 0.0054 (0.0054)  loss_rpn_box_reg: 0.0123 (0.0123)  time: 2.3224  data: 0.5672  max mem: 8473
# Epoch: [5]  [2/3]  eta: 0:00:01  lr: 0.000500  loss: 0.2006 (0.1894)  loss_classifier: 0.0967 (0.0829)  loss_box_reg: 0.0964 (0.0967)  loss_objectness: 0.0033 (0.0037)  loss_rpn_box_reg: 0.0039 (0.0061)  time: 1.4156  data: 0.2011  max mem: 8473
# Epoch: [5] Total time: 0:00:04 (1.4470 s / it)
# creating index...
# index created!
# Test:  [0/1]  eta: 0:00:00  model_time: 0.6950 (0.6950)  evaluator_time: 0.0041 (0.0041)  time: 0.9852  data: 0.2786  max mem: 8473
# Test: Total time: 0:00:01 (1.0822 s / it)
# Averaged stats: model_time: 0.6950 (0.6950)  evaluator_time: 0.0041 (0.0041)
# Accumulating evaluation results...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.407
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.838
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.252
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.407
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.478
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.478
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.478
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.478
# Epoch: [6]  [0/3]  eta: 0:00:06  lr: 0.000050  loss: 0.1695 (0.1695)  loss_classifier: 0.0687 (0.0687)  loss_box_reg: 0.0856 (0.0856)  loss_objectness: 0.0069 (0.0069)  loss_rpn_box_reg: 0.0084 (0.0084)  time: 2.1739  data: 0.4425  max mem: 8473
# Epoch: [6]  [2/3]  eta: 0:00:01  lr: 0.000050  loss: 0.1661 (0.1469)  loss_classifier: 0.0687 (0.0555)  loss_box_reg: 0.0823 (0.0733)  loss_objectness: 0.0069 (0.0079)  loss_rpn_box_reg: 0.0084 (0.0103)  time: 1.3677  data: 0.1503  max mem: 8473
# Epoch: [6] Total time: 0:00:04 (1.4011 s / it)
# creating index...
# index created!
# Test:  [0/1]  eta: 0:00:01  model_time: 0.7001 (0.7001)  evaluator_time: 0.0040 (0.0040)  time: 1.0143  data: 0.3026  max mem: 8473
# Test: Total time: 0:00:01 (1.1045 s / it)
# Averaged stats: model_time: 0.7001 (0.7001)  evaluator_time: 0.0040 (0.0040)
# Accumulating evaluation results...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.407
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.838
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.252
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.407
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.478
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.478
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.478
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.478
# Epoch: [7]  [0/3]  eta: 0:00:06  lr: 0.000050  loss: 0.1776 (0.1776)  loss_classifier: 0.0740 (0.0740)  loss_box_reg: 0.0918 (0.0918)  loss_objectness: 0.0067 (0.0067)  loss_rpn_box_reg: 0.0052 (0.0052)  time: 2.2558  data: 0.4822  max mem: 8473
# Epoch: [7]  [2/3]  eta: 0:00:01  lr: 0.000050  loss: 0.1661 (0.1655)  loss_classifier: 0.0633 (0.0668)  loss_box_reg: 0.0918 (0.0860)  loss_objectness: 0.0067 (0.0053)  loss_rpn_box_reg: 0.0079 (0.0074)  time: 1.4107  data: 0.1741  max mem: 8473
# Epoch: [7] Total time: 0:00:04 (1.4421 s / it)
# creating index...
# index created!
# Test:  [0/1]  eta: 0:00:01  model_time: 0.7041 (0.7041)  evaluator_time: 0.0043 (0.0043)  time: 1.0037  data: 0.2876  max mem: 8473
# Test: Total time: 0:00:01 (1.1002 s / it)
# Averaged stats: model_time: 0.7041 (0.7041)  evaluator_time: 0.0043 (0.0043)
# Accumulating evaluation results...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.407
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.838
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.252
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.407
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.478
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.478
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.478
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.478
# Epoch: [8]  [0/3]  eta: 0:00:06  lr: 0.000050  loss: 0.1670 (0.1670)  loss_classifier: 0.0701 (0.0701)  loss_box_reg: 0.0805 (0.0805)  loss_objectness: 0.0099 (0.0099)  loss_rpn_box_reg: 0.0065 (0.0065)  time: 2.1914  data: 0.4424  max mem: 8473
# Epoch: [8]  [2/3]  eta: 0:00:01  lr: 0.000050  loss: 0.1670 (0.1571)  loss_classifier: 0.0681 (0.0586)  loss_box_reg: 0.0809 (0.0821)  loss_objectness: 0.0076 (0.0065)  loss_rpn_box_reg: 0.0068 (0.0099)  time: 1.3878  data: 0.1505  max mem: 8473
# Epoch: [8] Total time: 0:00:04 (1.4222 s / it)
# creating index...
# index created!
# Test:  [0/1]  eta: 0:00:00  model_time: 0.7045 (0.7045)  evaluator_time: 0.0041 (0.0041)  time: 0.9945  data: 0.2784  max mem: 8473
# Test: Total time: 0:00:01 (1.0913 s / it)
# Averaged stats: model_time: 0.7045 (0.7045)  evaluator_time: 0.0041 (0.0041)
# Accumulating evaluation results...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.407
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.838
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.252
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.407
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.478
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.478
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.478
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.478
# Epoch: [9]  [0/3]  eta: 0:00:06  lr: 0.000005  loss: 0.1793 (0.1793)  loss_classifier: 0.0745 (0.0745)  loss_box_reg: 0.0908 (0.0908)  loss_objectness: 0.0072 (0.0072)  loss_rpn_box_reg: 0.0068 (0.0068)  time: 2.2312  data: 0.4803  max mem: 8473
# Epoch: [9]  [2/3]  eta: 0:00:01  lr: 0.000005  loss: 0.1551 (0.1542)  loss_classifier: 0.0640 (0.0593)  loss_box_reg: 0.0790 (0.0785)  loss_objectness: 0.0062 (0.0054)  loss_rpn_box_reg: 0.0068 (0.0110)  time: 1.4088  data: 0.1640  max mem: 8473
# Epoch: [9] Total time: 0:00:04 (1.4871 s / it)
# creating index...
# index created!
# Test:  [0/1]  eta: 0:00:01  model_time: 0.7123 (0.7123)  evaluator_time: 0.0040 (0.0040)  time: 1.0063  data: 0.2811  max mem: 8473
# Test: Total time: 0:00:01 (1.0957 s / it)
# Averaged stats: model_time: 0.7123 (0.7123)  evaluator_time: 0.0040 (0.0040)
# Accumulating evaluation results...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.407
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.838
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.252
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.407
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.478
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.478
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.478
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.478
# Epoch: [10]  [0/3]  eta: 0:00:07  lr: 0.000005  loss: 0.1607 (0.1607)  loss_classifier: 0.0711 (0.0711)  loss_box_reg: 0.0781 (0.0781)  loss_objectness: 0.0056 (0.0056)  loss_rpn_box_reg: 0.0060 (0.0060)  time: 2.3903  data: 0.6246  max mem: 8473
# Epoch: [10]  [2/3]  eta: 0:00:01  lr: 0.000005  loss: 0.1675 (0.1735)  loss_classifier: 0.0711 (0.0696)  loss_box_reg: 0.0879 (0.0898)  loss_objectness: 0.0077 (0.0077)  loss_rpn_box_reg: 0.0060 (0.0064)  time: 1.4682  data: 0.2204  max mem: 8473
# Epoch: [10] Total time: 0:00:04 (1.5004 s / it)
# creating index...
# index created!
# Test:  [0/1]  eta: 0:00:01  model_time: 0.7171 (0.7171)  evaluator_time: 0.0039 (0.0039)  time: 1.0241  data: 0.2953  max mem: 8473
# Test: Total time: 0:00:01 (1.1140 s / it)
# Averaged stats: model_time: 0.7171 (0.7171)  evaluator_time: 0.0039 (0.0039)
# Accumulating evaluation results...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.407
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.838
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.252
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.407
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.478
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.478
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.478
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.478
# Epoch: [11]  [0/3]  eta: 0:00:06  lr: 0.000005  loss: 0.1843 (0.1843)  loss_classifier: 0.0744 (0.0744)  loss_box_reg: 0.0983 (0.0983)  loss_objectness: 0.0050 (0.0050)  loss_rpn_box_reg: 0.0065 (0.0065)  time: 2.2433  data: 0.4612  max mem: 8473
# Epoch: [11]  [2/3]  eta: 0:00:01  lr: 0.000005  loss: 0.1843 (0.1852)  loss_classifier: 0.0744 (0.0857)  loss_box_reg: 0.0922 (0.0864)  loss_objectness: 0.0075 (0.0080)  loss_rpn_box_reg: 0.0065 (0.0051)  time: 1.4277  data: 0.1583  max mem: 8473
# Epoch: [11] Total time: 0:00:04 (1.4737 s / it)
# creating index...
# index created!
# Test:  [0/1]  eta: 0:00:01  model_time: 0.7277 (0.7277)  evaluator_time: 0.0045 (0.0045)  time: 1.0382  data: 0.2982  max mem: 8473
# Test: Total time: 0:00:01 (1.1394 s / it)
# Averaged stats: model_time: 0.7277 (0.7277)  evaluator_time: 0.0045 (0.0045)
# Accumulating evaluation results...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.407
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.838
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.252
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.407
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.478
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.478
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.478
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.478
# Epoch: [12]  [0/3]  eta: 0:00:06  lr: 0.000001  loss: 0.1368 (0.1368)  loss_classifier: 0.0487 (0.0487)  loss_box_reg: 0.0661 (0.0661)  loss_objectness: 0.0099 (0.0099)  loss_rpn_box_reg: 0.0120 (0.0120)  time: 2.1962  data: 0.3905  max mem: 8473
# Epoch: [12]  [2/3]  eta: 0:00:01  lr: 0.000001  loss: 0.1897 (0.1908)  loss_classifier: 0.0811 (0.0717)  loss_box_reg: 0.0976 (0.0964)  loss_objectness: 0.0099 (0.0171)  loss_rpn_box_reg: 0.0023 (0.0056)  time: 1.4140  data: 0.1424  max mem: 8473
# Epoch: [12] Total time: 0:00:04 (1.4468 s / it)
# creating index...
# index created!
# Test:  [0/1]  eta: 0:00:01  model_time: 0.7303 (0.7303)  evaluator_time: 0.0039 (0.0039)  time: 1.0227  data: 0.2809  max mem: 8473
# Test: Total time: 0:00:01 (1.1210 s / it)
# Averaged stats: model_time: 0.7303 (0.7303)  evaluator_time: 0.0039 (0.0039)
# Accumulating evaluation results...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.407
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.838
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.252
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.407
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.478
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.478
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.478
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.478
# Epoch: [13]  [0/3]  eta: 0:00:06  lr: 0.000001  loss: 0.1759 (0.1759)  loss_classifier: 0.0743 (0.0743)  loss_box_reg: 0.0905 (0.0905)  loss_objectness: 0.0053 (0.0053)  loss_rpn_box_reg: 0.0058 (0.0058)  time: 2.2886  data: 0.4701  max mem: 8473
# Epoch: [13]  [2/3]  eta: 0:00:01  lr: 0.000001  loss: 0.1759 (0.1683)  loss_classifier: 0.0743 (0.0715)  loss_box_reg: 0.0781 (0.0817)  loss_objectness: 0.0063 (0.0097)  loss_rpn_box_reg: 0.0058 (0.0054)  time: 1.4501  data: 0.1604  max mem: 8473
# Epoch: [13] Total time: 0:00:04 (1.4954 s / it)
# creating index...
# index created!
# Test:  [0/1]  eta: 0:00:01  model_time: 0.7377 (0.7377)  evaluator_time: 0.0039 (0.0039)  time: 1.1058  data: 0.3558  max mem: 8473
# Test: Total time: 0:00:01 (1.1962 s / it)
# Averaged stats: model_time: 0.7377 (0.7377)  evaluator_time: 0.0039 (0.0039)
# Accumulating evaluation results...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.407
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.838
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.252
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.407
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.478
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.478
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.478
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.478
# Epoch: [14]  [0/3]  eta: 0:00:06  lr: 0.000001  loss: 0.1441 (0.1441)  loss_classifier: 0.0526 (0.0526)  loss_box_reg: 0.0746 (0.0746)  loss_objectness: 0.0058 (0.0058)  loss_rpn_box_reg: 0.0111 (0.0111)  time: 2.2777  data: 0.4202  max mem: 8473
# Epoch: [14]  [2/3]  eta: 0:00:01  lr: 0.000001  loss: 0.1783 (0.1680)  loss_classifier: 0.0782 (0.0808)  loss_box_reg: 0.0746 (0.0780)  loss_objectness: 0.0048 (0.0037)  loss_rpn_box_reg: 0.0033 (0.0054)  time: 1.4597  data: 0.1524  max mem: 8473
# Epoch: [14] Total time: 0:00:04 (1.4939 s / it)
# creating index...
# index created!
# Test:  [0/1]  eta: 0:00:01  model_time: 0.7521 (0.7521)  evaluator_time: 0.0042 (0.0042)  time: 1.0559  data: 0.2912  max mem: 8473
# Test: Total time: 0:00:01 (1.1542 s / it)
# Averaged stats: model_time: 0.7521 (0.7521)  evaluator_time: 0.0042 (0.0042)
# Accumulating evaluation results...
# DONE (t=0.00s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.407
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.838
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.252
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.407
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.478
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.478
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.478
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.478

# %%
# the function takes the original prediction and the iou threshold.

def apply_nms(orig_prediction, iou_thresh=0.3):
    
    # torchvision returns the indices of the bboxes to keep
    keep = torchvision.ops.nms(orig_prediction['boxes'].cpu(), orig_prediction['scores'].cpu(), iou_thresh)
    
    final_prediction = orig_prediction
    final_prediction['boxes'] = final_prediction['boxes'].cpu()[keep]
    final_prediction['scores'] = final_prediction['scores'].cpu()[keep]
    final_prediction['labels'] = final_prediction['labels'].cpu()[keep]
    
    return final_prediction

# function to convert a torchtensor back to PIL image
def torch_to_pil(img):
    return torchtrans.ToPILImage()(img).convert('RGB')

# %%
#test_dataset = ConeImagesDataset(test_dir, 480, 480, transforms= get_transform(train=True))

# pick one image from the test set
img, target = dataset_test[8]
# put the model in evaluation mode
model.eval()
with torch.no_grad():
    prediction = model([img.to(device)])[0]
    
print('predicted #boxes: ', len(prediction['labels']))
print('real #boxes: ', len(target['labels']))
# Out:
# predicted #boxes:  1
# real #boxes:  1

# %%
print('EXPECTED OUTPUT')
#print(target)
plot_img_bbox(torch_to_pil(img), target)
# Out:
# EXPECTED OUTPUT
# {'boxes': tensor([[134.4000,  28.8000, 345.6000, 448.3200]]), 'labels': tensor([1]), 'area': tensor([88602.6328]), 'iscrowd': tensor([0]), 'image_id': tensor([28])}

# %%
print('MODEL OUTPUT')
print(prediction)
plot_img_bbox(torch_to_pil(img), prediction)

# %%
nms_prediction = apply_nms(prediction, iou_thresh=0.1)
print('NMS APPLIED MODEL OUTPUT')
plot_img_bbox(torch_to_pil(img), nms_prediction)
# Out:
# NMS APPLIED MODEL OUTPUT

# %%
print('EXPECTED OUTPUT')
plot_img_bbox(torch_to_pil(img), target)
print('MODEL OUTPUT')
plot_img_bbox(torch_to_pil(img), nms_prediction)
# Out:
# EXPECTED OUTPUT
# MODEL OUTPUT
